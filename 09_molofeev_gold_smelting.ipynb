# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Изучение-данных." data-toc-modified-id="Изучение-данных.-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Изучение данных.</a></span></li><li><span><a href="#Расчет-эффективности-обогащения." data-toc-modified-id="Расчет-эффективности-обогащения.-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Расчет эффективности обогащения.</a></span></li><li><span><a href="#Изучение-данных,-недоступных-в-тестовой-выборке." data-toc-modified-id="Изучение-данных,-недоступных-в-тестовой-выборке.-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Изучение данных, недоступных в тестовой выборке.</a></span></li><li><span><a href="#Предобработка-данных." data-toc-modified-id="Предобработка-данных.-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Предобработка данных.</a></span></li></ul></li><li><span><a href="#Анализ-данных." data-toc-modified-id="Анализ-данных.-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Анализ данных.</a></span><ul class="toc-item"><li><span><a href="#Анализ-концентрации-сырья-на-различных-этапах-выборки." data-toc-modified-id="Анализ-концентрации-сырья-на-различных-этапах-выборки.-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Анализ концентрации сырья на различных этапах выборки.</a></span></li><li><span><a href="#Распределение-размеров-гранул-сырья-на-обучающей-и-тестовой-выборках." data-toc-modified-id="Распределение-размеров-гранул-сырья-на-обучающей-и-тестовой-выборках.-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Распределение размеров гранул сырья на обучающей и тестовой выборках.</a></span></li><li><span><a href="#Исследование-суммарной-концентрации-всех-веществ-на-разных-стадиях." data-toc-modified-id="Исследование-суммарной-концентрации-всех-веществ-на-разных-стадиях.-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Исследование суммарной концентрации всех веществ на разных стадиях.</a></span></li></ul></li><li><span><a href="#Модель." data-toc-modified-id="Модель.-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Модель.</a></span><ul class="toc-item"><li><span><a href="#Написание-функции-для-определения-итоговой-sMARE." data-toc-modified-id="Написание-функции-для-определения-итоговой-sMARE.-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Написание функции для определения итоговой sMARE.</a></span></li><li><span><a href="#Обучение-и-проверка-моделей." data-toc-modified-id="Обучение-и-проверка-моделей.-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Обучение и проверка моделей.</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Восстановление золота из руды

# %% [markdown]
# Подготовьте прототип модели машинного обучения для «Цифры». Компания разрабатывает решения для эффективной работы промышленных предприятий.
#
# Модель должна предсказать коэффициент восстановления золота из золотосодержащей руды. Используйте данные с параметрами добычи и очистки.
#
# Модель поможет оптимизировать производство, чтобы не запускать предприятие с убыточными характеристиками.
#
# Вам нужно:
#
# 1. Подготовить данные;
# 2. Провести исследовательский анализ данных;
# 3. Построить и обучить модель.
#
# Чтобы выполнить проект, обращайтесь к библиотекам *pandas*, *matplotlib* и *sklearn.* Вам поможет их документация.

# %% [markdown]
# **Описание данных**
#
# Данные находятся в трёх файлах:
# - `gold_recovery_train_new.csv` — обучающая выборка;
# - `gold_recovery_test_new.csv` — тестовая выборка;
# - `gold_recovery_full_new.csv` — исходные данные.
#
# Данные индексируются датой и временем получения информации (признак date). Соседние по времени параметры часто похожи.
# Некоторые параметры недоступны, потому что замеряются и/или рассчитываются значительно позже. Из-за этого в тестовой выборке отсутствуют некоторые признаки, которые могут быть в обучающей. Также в тестовом наборе нет целевых признаков.
# Исходный датасет содержит обучающую и тестовую выборки со всеми признаками.
# В вашем распоряжении сырые данные: их просто выгрузили из хранилища. Прежде чем приступить к построению модели, проверьте по нашей инструкции их на корректность.

# %% [markdown]
# **Ход проекта:**
# 1. Изучение и подготовка данных (изучение данных, проверка правильности расчета эффективности обогащения, анализ признаков, недоступных в тестовой выборе, предобработка данных).
# 2. Исследовательский анализ данных (изучение изменения концентрации металлов на разных этапах обработки, сравнение распределения размеров гранул сырья в обучающей и тестовой выборках, исследование суммарной концентрации всех веществ на разных этапах).
# 3. Построение модели (создание функции для расчета итоговой sMARE, обучение моделей, проверка их качества кросс-валидацией и проверка качества лучшей модели на тестовой выборке).

# %% [markdown]
# **Цель проекта:** Обучить модель, дающую лучший вариант sMARE.

# %% [markdown]
# ## Подготовка данных

# %% [markdown]
# ### Изучение данных.

# %% [markdown]
# Загрузим необходимые для работы библиотеки.

# %%
import pandas as pd
import numpy as np

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import make_scorer

from sklearn.impute import KNNImputer

from sklearn.preprocessing import StandardScaler

from sklearn.pipeline import make_pipeline

from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV


from sklearn.linear_model import Lasso
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor

from sklearn.dummy import DummyRegressor

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# По условиям проекта у нас имеется три датасета - обучающая выборка, тестовая выборка, исходные данные. Загрузим их и посмотрим информацию о фреймах.

# %%
try:
    df_train = pd.read_csv('https://code.s3.yandex.net/datasets/gold_recovery_train_new.csv')
    df_test = pd.read_csv('https://code.s3.yandex.net/datasets/gold_recovery_test_new.csv')
    df_full = pd.read_csv('https://code.s3.yandex.net/datasets/gold_recovery_full_new.csv')
except:
    df_train = pd.read_csv('D:/learn_data/gold_recovery_train_new.csv')
    df_test = pd.read_csv('D:/learn_data/gold_recovery_test_new.csv')
    df_full = pd.read_csv('D:/learn_data/gold_recovery_full_new.csv')

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14149 entries, 0 to 14148
# Data columns (total 87 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   date                                                14149 non-null  object
#  1   final.output.concentrate_ag                         14148 non-null  float64
#  2   final.output.concentrate_pb                         14148 non-null  float64
#  3   final.output.concentrate_sol                        13938 non-null  float64
#  4   final.output.concentrate_au                         14149 non-null  float64
#  5   final.output.recovery                               14149 non-null  float64
#  6   final.output.tail_ag                                14149 non-null  float64
#  7   final.output.tail_pb                                14049 non-null  float64
# ...

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5290 entries, 0 to 5289
# Data columns (total 53 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   date                                        5290 non-null   object
#  1   primary_cleaner.input.sulfate               5286 non-null   float64
#  2   primary_cleaner.input.depressant            5285 non-null   float64
#  3   primary_cleaner.input.feed_size             5290 non-null   float64
#  4   primary_cleaner.input.xanthate              5286 non-null   float64
#  5   primary_cleaner.state.floatbank8_a_air      5290 non-null   float64
#  6   primary_cleaner.state.floatbank8_a_level    5290 non-null   float64
#  7   primary_cleaner.state.floatbank8_b_air      5290 non-null   float64
#  8   primary_cleaner.state.floatbank8_b_level    5290 non-null   float64
# ...

# %%
df_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19439 entries, 0 to 19438
# Data columns (total 87 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   date                                                19439 non-null  object
#  1   final.output.concentrate_ag                         19438 non-null  float64
#  2   final.output.concentrate_pb                         19438 non-null  float64
#  3   final.output.concentrate_sol                        19228 non-null  float64
#  4   final.output.concentrate_au                         19439 non-null  float64
#  5   final.output.recovery                               19439 non-null  float64
#  6   final.output.tail_ag                                19438 non-null  float64
#  7   final.output.tail_pb                                19338 non-null  float64
# ...

# %%
print(df_train.shape)
print(df_test.shape)
print(df_full.shape)
# Out:
# (14149, 87)
# (5290, 53)
# (19439, 87)

# %% [markdown]
# Как мы видим количество столбцов в обучающей выборке и исходных данных *87*, тогда как в тестовой выборке только *53*. Также имеются пропуски, давайте взглянем на их количество в каждом датафрейме.

# %%
print('Количество пропусков в тестовой выборке:', df_test.isnull().sum().sum())
print('Количество пропусков в обучающей выборке:', df_train.isnull().sum().sum())
print('Количество пропусков в исходных данных:', df_full.isnull().sum().sum())
# Out:
# Количество пропусков в тестовой выборке: 90
# Количество пропусков в обучающей выборке: 4100
# Количество пропусков в исходных данных: 4481

# %% [markdown]
# ### Расчет эффективности обогащения.

# %% [markdown]
# Рассчитаем эффективность обогащения чернового концентрата `rougher.output.recovery` из обучающей выборки. Предварительно удалим пропуски из столбцов со значением NaN.

# %%
df_train.dropna(subset=['rougher.output.concentrate_au', 'rougher.input.feed_au',
                                   'rougher.output.tail_au','rougher.output.recovery'], inplace=True)
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14149 entries, 0 to 14148
# Data columns (total 87 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   date                                                14149 non-null  object
#  1   final.output.concentrate_ag                         14148 non-null  float64
#  2   final.output.concentrate_pb                         14148 non-null  float64
#  3   final.output.concentrate_sol                        13938 non-null  float64
#  4   final.output.concentrate_au                         14149 non-null  float64
#  5   final.output.recovery                               14149 non-null  float64
#  6   final.output.tail_ag                                14149 non-null  float64
#  7   final.output.tail_pb                                14049 non-null  float64
# ...

# %%
concentrate_au = df_train['rougher.output.concentrate_au']
feed_au = df_train['rougher.input.feed_au']
tail_au = df_train['rougher.output.tail_au']
input_recovery = df_train['rougher.output.recovery']
calculated_recovery = concentrate_au * (feed_au - tail_au) / (feed_au * (concentrate_au - tail_au)) * 100
print('Абсолютная средняя ошибка =', mean_absolute_error(input_recovery, calculated_recovery))
# Out:
# Абсолютная средняя ошибка = 9.73512347450521e-15

# %% [markdown]
# Как мы видим, MAE имеет очень малое отклонение, а это значит, что расчетное значение `rougher.output.recovery` совпадает с данными из столбца.

# %% [markdown]
# ### Изучение данных, недоступных в тестовой выборке.

# %% [markdown]
# Теперь изучим признаки, которые отсутствуют в тестовой выборке. Посмотрим на их количеств и наименования.

# %%
df_train.shape[1] - df_test.shape[1]
# Out:
# 34

# %%
df_train.columns.drop(df_test.columns)
# Out:
# Index(['final.output.concentrate_ag', 'final.output.concentrate_pb',
#        'final.output.concentrate_sol', 'final.output.concentrate_au',
#        'final.output.recovery', 'final.output.tail_ag', 'final.output.tail_pb',
#        'final.output.tail_sol', 'final.output.tail_au',
#        'primary_cleaner.output.concentrate_ag',
#        'primary_cleaner.output.concentrate_pb',
#        'primary_cleaner.output.concentrate_sol',
#        'primary_cleaner.output.concentrate_au',
#        'primary_cleaner.output.tail_ag', 'primary_cleaner.output.tail_pb',
#        'primary_cleaner.output.tail_sol', 'primary_cleaner.output.tail_au',
#        'rougher.calculation.sulfate_to_au_concentrate',
#        'rougher.calculation.floatbank10_sulfate_to_au_feed',
#        'rougher.calculation.floatbank11_sulfate_to_au_feed',
#        'rougher.calculation.au_pb_ratio', 'rougher.output.concentrate_ag',
#        'rougher.output.concentrate_pb', 'rougher.output.concentrate_sol',
# ...

# %% [markdown]
# Таким образом, в тестовой выборке у нас отсутствуют столбцы этапов `final.output`, `primary_cleaner.output`, `rougher.calculation`, `rougher.output` и `secondary_cleaner.output`, то есть все этапы, на которых были получены параметры продукта из сырья (конечные значения после каждого этапа обработки). Эти данные получены по результатам технологического процесса, то есть это ***онлайн метрики***. Остальные столбцы исторически известны - значит это ***офлайн метрики***.

# %% [markdown]
# ### Предобработка данных.

# %% [markdown]
# Сначала взглянем на то, имеются ли в данных дубликаты.

# %%
df_train.duplicated().sum()
# Out:
# 0

# %%
df_test.duplicated().sum()
# Out:
# 0

# %%
df_full.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Дубликатов нет. Затем удалим не нужные нам столбцы.

# %%
print('Количество пропусков в обучающей выборке:', df_train['final.output.recovery'].isnull().sum())
print('Количество пропусков в обучающей выборке:', df_train['rougher.output.recovery'].isnull().sum())
# Out:
# Количество пропусков в обучающей выборке: 0
# Количество пропусков в обучающей выборке: 0

# %%
drop_test = df_train.columns.drop(df_test.columns)
df_train.drop(drop_test, axis=1, inplace=True)

# %% [markdown]
# Далее предлагаю преобразовать значения столбца `data`, которые не имеют значения для обучения модели, в индекс.

# %%
df_train.set_index('date', inplace=True)
df_test.set_index('date', inplace=True)
df_full.set_index('date', inplace=True)

# %% [markdown]
# Заполним пропуски c помощью метода k-ближайших соседей.

# %%
def transform_imputer(data, n_neighbors):

    data_columns = data.columns
    index = data.index
    imputer = KNNImputer(n_neighbors=n_neighbors)
    imputer.fit_transform(df_train)
    

    return pd.DataFrame(imputer.transform(data), columns=data_columns, index=index)

# %%
df_train_new = transform_imputer(df_train, 5)
df_test_new = transform_imputer(df_test, 5)

# %%
print('Количество пропусков до обработки данных в обучающей выборке:', df_train.isnull().sum().sum())
print('Количество пропусков после обработки данных в обучающей выборке:', df_train_new.isnull().sum().sum())
print('Количество пропусков до обработки данных в тестовой выборке:', df_test.isnull().sum().sum())
print('Количество пропусков после обработки данных в тестовой выборке:', df_test_new.isnull().sum().sum())
# Out:
# Количество пропусков до обработки данных в обучающей выборке: 1705
# Количество пропусков после обработки данных в обучающей выборке: 0
# Количество пропусков до обработки данных в тестовой выборке: 90
# Количество пропусков после обработки данных в тестовой выборке: 0

# %% [markdown]
# **Вывод:**
#
# Были изучены данные трех фреймов, представляющие собой полный сет данных и две выборки (обучающую и тестовую). Пр этом в тестовой выборке отсутствовали 34 столбца, которые, как выяснилось, содержат данные, получаемые в ходе технологического процесса. Установлено, что расчетное значение `rougher.output.recovery` совпадает с данными соответствующего столбца (абсолютная ошибка крайне незначительна). Затем в ходе предобработки были обработаны пропуски, а также столбец `data`, который не содержал имеющих значение данных, был преобразован в индекс.

# %% [markdown]
# ## Анализ данных.

# %% [markdown]
# ### Анализ концентрации сырья на различных этапах выборки.

# %% [markdown]
# Очевидно, что анализ данных мы будем проводить по полным данным, лишь при необходимости подключая обучающую и тестовую выборки.

# %% [markdown]
# В 87 столбцах нужные нам значения отберём их по названию металла в столбцах.

# %%
df_full.columns[df_full.columns.str.endswith('au')], df_full.columns[df_full.columns.str.endswith('ag')],\
df_full.columns[df_full.columns.str.endswith('pb')]
# Out:
# (Index(['final.output.concentrate_au', 'final.output.tail_au',
#         'primary_cleaner.output.concentrate_au',
#         'primary_cleaner.output.tail_au', 'rougher.input.feed_au',
#         'rougher.output.concentrate_au', 'rougher.output.tail_au',
#         'secondary_cleaner.output.tail_au'],
#        dtype='object'),
#  Index(['final.output.concentrate_ag', 'final.output.tail_ag',
#         'primary_cleaner.output.concentrate_ag',
#         'primary_cleaner.output.tail_ag', 'rougher.input.feed_ag',
#         'rougher.output.concentrate_ag', 'rougher.output.tail_ag',
#         'secondary_cleaner.output.tail_ag'],
#        dtype='object'),
#  Index(['final.output.concentrate_pb', 'final.output.tail_pb',
#         'primary_cleaner.output.concentrate_pb',
#         'primary_cleaner.output.tail_pb', 'rougher.input.feed_pb',
#         'rougher.output.concentrate_pb', 'rougher.output.tail_pb',
#         'secondary_cleaner.output.tail_pb'],
#        dtype='object'))

# %% [markdown]
# Отберём нужные нам столбцы:
# - сырьё в исходном виде;
# - после флотации;
# - после первичной обработки;
# - финальный концентрат.

# %%
AU = df_full[['rougher.input.feed_au', 'rougher.output.concentrate_au', 'primary_cleaner.output.concentrate_au', 
            'final.output.concentrate_au']].dropna()
AG = df_full[['rougher.input.feed_ag', 'rougher.output.concentrate_ag', 'primary_cleaner.output.concentrate_ag', 
            'final.output.concentrate_ag']].dropna()
PB = df_full[['rougher.input.feed_pb', 'rougher.output.concentrate_pb', 'primary_cleaner.output.concentrate_pb', 
            'final.output.concentrate_pb']].dropna()

# %% [markdown]
# Теперь посмотрим как меняется концентрация металлов на разных стадиях очистки.

# %%
print('Концентрация до флотации:')
print(f"серебро:{AG['rougher.input.feed_ag'].median(): 0.2f},\
свинец:{PB['rougher.input.feed_pb'].median(): 0.2f},\
золото:{AU['rougher.input.feed_au'].median(): 0.2f}")
print()
print('Концентрация после флотации:')
print(f"серебро:{AG['rougher.output.concentrate_ag'].median(): 0.2f},\
свинец:{PB['rougher.output.concentrate_pb'].median(): 0.2f},\
золото:{AU['rougher.output.concentrate_au'].median(): 0.2f}")
print()
print('Концентрация после первичной очистки:')
print(f"серебро:{AG['primary_cleaner.output.concentrate_ag'].median(): 0.2f},\
свинец:{PB['primary_cleaner.output.concentrate_pb'].median(): 0.2f},\
золото:{AU['primary_cleaner.output.concentrate_au'].median(): 0.2f}")
print()
print('Финальный концентрат:')
print(f"серебро:{AG['final.output.concentrate_ag'].median(): 0.2f},\
свинец:{PB['final.output.concentrate_pb'].median(): 0.2f},\
золото:{AU['final.output.concentrate_au'].median(): 0.2f}")
# Out:
# Концентрация до флотации:
# серебро: 8.59,свинец: 3.54,золото: 8.13
#
# Концентрация после флотации:
# серебро: 12.10,свинец: 7.75,золото: 20.28
#
# Концентрация после первичной очистки:
# серебро: 8.51,свинец: 10.16,золото: 32.84
#
# Финальный концентрат:
# серебро: 5.07,свинец: 10.12,золото: 45.01

# %% [markdown]
# Взглянем на концентрацию металлов на различных этапах на графиках. Посмотрим на изменение концентрации золота.

# %%
sns.displot(AU, kind='kde')
plt.xlabel('Концентрация золота')
plt.ylabel('Плотность распределения')
plt.title('Изменение концентрации золота после разных этапов обработки');

# %% [markdown]
# Теперь взглянем на изменение концентрации свинца.

# %%
sns.displot(PB, kind='kde')
plt.xlabel('Концентрация свинца')
plt.ylabel('Плотность распределения')
plt.title('Изменение концентрации свинца после разных этапов обработки');

# %% [markdown]
# Посмотрим и на изменение концентрации серебра.

# %%
sns.displot(AG, kind='kde')
plt.xlabel('Концентрация серебра')
plt.ylabel('Плотность распределения')
plt.title('Изменение концентрации серебра после разных этапов обработки');

# %% [markdown]
# Итак, можно наблюдать что с каждым этапом очистки концентрация золота заметно увеличивается, в то время как концентрация серебра наоборот снижается, свинец же показывает небольшое увеличение концентрации.

# %% [markdown]
# ### Распределение размеров гранул сырья на обучающей и тестовой выборках.

# %% [markdown]
# Чтобы посмотреть на распределение гранул сырья в обучающей и тестовой выборках в целях их сравнения, предлагаем взглянуть на данные в форме графиков.

# %%
df_test_new['rougher.input.feed_size'].hist(figsize=(15, 10), bins=60, alpha=1, density=True)
df_train_new['rougher.input.feed_size'].hist(figsize=(15, 10), bins=60, alpha=0.5, density=True)
plt.legend(['тестовая выборка', 'обучающая выборка'])
plt.title('Распределения размеров гранул сырья перед флотацией')
plt.xlabel('размер')
plt.ylabel('плотность распределения');

# %% [markdown]
# Как мы видим, распределения размера гранул сырья на тестовой и обучающей выборках перед флотацией не сильно отличаются друг от друга.

# %%
df_test_new['primary_cleaner.input.feed_size'].hist(figsize=(15, 10), bins=60, alpha=1, density=True)
df_train_new['primary_cleaner.input.feed_size'].hist(figsize=(15, 10), bins=60, alpha=0.5, density=True)
plt.legend(['тестовая выборка', 'обучающая выборка'])
plt.title('Распределения размеров гранул сырья перед первичной очисткой')
plt.xlabel('размер')
plt.ylabel('плотность распределения');

# %% [markdown]
# Распределения размера гранул сырья на тестовой и обучающей выборках перед первичной очисткой таке не сильно отличаются друг от друга, оценка модели будет правильной.

# %% [markdown]
# ### Исследование суммарной концентрации всех веществ на разных стадиях.

# %% [markdown]
# Для рассмотрения этого вопроса также разумно будет взглянуть на графики концентрации суммы всех веществ на графике. Первоначально надо сложить концентрацию всех веществ на каждом из этапов.

# %%
feed_concentrate = df_full['rougher.input.feed_ag'] + df_full['rougher.input.feed_pb'] +\
            df_full['rougher.input.feed_sol'] + df_full['rougher.input.feed_au']
rougher_concentrate = df_full['rougher.output.concentrate_ag'] + df_full['rougher.output.concentrate_pb'] +\
            df_full['rougher.output.concentrate_sol'] + df_full['rougher.output.concentrate_au']
final_concentrate = df_full['final.output.concentrate_ag'] + df_full['final.output.concentrate_pb'] +\
            df_full['final.output.concentrate_sol'] + df_full['final.output.concentrate_au']

# %%
feed_concentrate.hist(figsize=(15, 10), bins=60, alpha=1, density=True)
rougher_concentrate.hist(figsize=(15, 10), bins=60, alpha=0.5, density=True)
final_concentrate.hist(figsize=(15, 10), bins=60, alpha=0.5, density=True)
plt.legend(['Сырьё', 'черновой концентрат', 'финальный концентрат'])
plt.title('Суммарная концентрация всех веществ на разных стадиях')
plt.xlabel('концентрация')
plt.ylabel('плотность');

# %% [markdown]
# Как видно из графика, в черновом концентрате по сравнению с сырьем увеличивается концентрация суммарного количества веществ, а в финальном концентрате увеличивается плотность их распределения.
# Также мы видим, что имеются аномальные значения, которые лежат где-то около нуля. Так что примерно до 20 можно смело удалить для построения более точной модели, но для сырья поставим значение меньше 1, поскольку нам не известно в каком виде может поступать сырьё на производство.

# %%
df_full = df_full.query('@feed_concentrate > 1 & @rougher_concentrate > 20 & @final_concentrate > 20')

# %% [markdown]
# Подготовим выборки для обучения. Для этого добавим целевые признаки по индексам, чтобы индексы в обеих выборках совпадали. Так мы исключим из тестовой и обучающей выборки выбросы, которые мы обнаружили в полных данных. Затем сравним данные до и после объединения.

# %%
good_df_for_train = pd.merge(df_train_new, df_full[['rougher.output.recovery', 'final.output.recovery']],
        left_index=True, right_index=True)

print('Количество строк до объединения в обучающей выборке', df_train_new.shape[0])
print('Количество строк после объединения в обучающей выборке', good_df_for_train.shape[0])
print()

good_df_for_test = pd.merge(df_test_new, df_full[['rougher.output.recovery', 'final.output.recovery']],
         left_index=True, right_index=True)

print('Количество строк до объединения в тестовой выборке', df_test_new.shape[0])
print('Количество строк после объединения в тестовой выборке', good_df_for_test.shape[0])
# Out:
# Количество строк до объединения в обучающей выборке 14149
# Количество строк после объединения в обучающей выборке 13365
#
# Количество строк до объединения в тестовой выборке 5290
# Количество строк после объединения в тестовой выборке 5128

# %% [markdown]
# Также давайте взглянем, не осталось ли у нас в подготовленной обучающей выборке пропусков.

# %%
good_df_for_train.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# **Вывод:**
#
# Мы изучили изменение концентрации металлов на различных этапах разработки, было установлено, что концентрация золота уверенно увеличивается с каждым этапом. В ходе анализа также было установлено, что распределение размеров гранул сырья в обучающей и тестовой выборках в целом совпадает, что позволит обучать модели. Также, в процессе исследования суммарной концентрации веществ мы избавились от аномалий, сведения о которых удалили также в обучающей и тестовой выборках.

# %% [markdown]
# ## Модель.

# %% [markdown]
# ### Написание функции для определения итоговой sMARE.

# %% [markdown]
# Перед обучением модели напишем функции для наших метрик.

# %%
def sMAPE(true, pred):
    return 100 / len(true) * np.sum(2 * np.abs(pred - true) / (np.abs(true) + np.abs(pred)))

# %%
def total_sMAPE(sMAPE_rougher, sMAPE_final):
    return (0.25 * sMAPE_rougher + 0.75 * sMAPE_final)

# %%
smape_score = make_scorer(sMAPE, greater_is_better=False)

# %% [markdown]
# ### Обучение и проверка моделей.

# %% [markdown]
# Первоначально разделим наши выборки на признаки и целевые признаки.

# %%
x_train = good_df_for_train.drop(['rougher.output.recovery', 'final.output.recovery'], axis=1)
y_train_rougher = good_df_for_train['rougher.output.recovery']
y_train_final = good_df_for_train['final.output.recovery']
x_test = good_df_for_test.drop(['rougher.output.recovery', 'final.output.recovery'], axis=1)
y_test_rougher = good_df_for_test['rougher.output.recovery']
y_test_final = good_df_for_test['final.output.recovery']

# %% [markdown]
# С помощью пайплайна автоматизируем процесс обучения моделей. Предлагаю использовать в проекте модели дерева, леса и Лассо.

# %%
lasso_model = make_pipeline(StandardScaler(), Lasso(random_state=3301))
treeregressor_model = make_pipeline(StandardScaler(), DecisionTreeRegressor(random_state=3301))
forestregressor_model = make_pipeline(StandardScaler(), RandomForestRegressor(random_state=3301))

# %% [markdown]
# Для передачи параметров для кросс-валидации посмотрим как они именуются у каждой модели.

# %%
lasso_model.get_params().keys()
# Out:
# dict_keys(['memory', 'steps', 'verbose', 'standardscaler', 'lasso', 'standardscaler__copy', 'standardscaler__with_mean', 'standardscaler__with_std', 'lasso__alpha', 'lasso__copy_X', 'lasso__fit_intercept', 'lasso__max_iter', 'lasso__normalize', 'lasso__positive', 'lasso__precompute', 'lasso__random_state', 'lasso__selection', 'lasso__tol', 'lasso__warm_start'])

# %%
treeregressor_model.get_params().keys()
# Out:
# dict_keys(['memory', 'steps', 'verbose', 'standardscaler', 'decisiontreeregressor', 'standardscaler__copy', 'standardscaler__with_mean', 'standardscaler__with_std', 'decisiontreeregressor__ccp_alpha', 'decisiontreeregressor__criterion', 'decisiontreeregressor__max_depth', 'decisiontreeregressor__max_features', 'decisiontreeregressor__max_leaf_nodes', 'decisiontreeregressor__min_impurity_decrease', 'decisiontreeregressor__min_samples_leaf', 'decisiontreeregressor__min_samples_split', 'decisiontreeregressor__min_weight_fraction_leaf', 'decisiontreeregressor__random_state', 'decisiontreeregressor__splitter'])

# %%
forestregressor_model.get_params().keys()
# Out:
# dict_keys(['memory', 'steps', 'verbose', 'standardscaler', 'randomforestregressor', 'standardscaler__copy', 'standardscaler__with_mean', 'standardscaler__with_std', 'randomforestregressor__bootstrap', 'randomforestregressor__ccp_alpha', 'randomforestregressor__criterion', 'randomforestregressor__max_depth', 'randomforestregressor__max_features', 'randomforestregressor__max_leaf_nodes', 'randomforestregressor__max_samples', 'randomforestregressor__min_impurity_decrease', 'randomforestregressor__min_samples_leaf', 'randomforestregressor__min_samples_split', 'randomforestregressor__min_weight_fraction_leaf', 'randomforestregressor__n_estimators', 'randomforestregressor__n_jobs', 'randomforestregressor__oob_score', 'randomforestregressor__random_state', 'randomforestregressor__verbose', 'randomforestregressor__warm_start'])

# %% [markdown]
# Теперь передадим параметры.

# %%
forestregressor_params = {'randomforestregressor__n_estimators':range(10, 61, 10),
             'randomforestregressor__max_depth':range(1,10)}
treeregressor_params= {'decisiontreeregressor__max_depth':range(1,10)}
lasso_params = {'lasso__alpha':[0.02, 0.024, 0.025, 0.026, 0.03]}

# %% [markdown]
# Напишем кросс-валидацию для модели Лассо.

# %%
grid_rougher_lasso = RandomizedSearchCV(lasso_model, param_distributions = lasso_params, cv=5,
                                            scoring = smape_score, n_jobs=-1)
grid_final_lasso = RandomizedSearchCV(lasso_model, param_distributions = lasso_params, cv=5,
                                            scoring = smape_score, n_jobs=-1)

# %% [markdown]
# Напишем кросс-валидацию для дерева.

# %%
grid_rougher_treeregressor = RandomizedSearchCV(treeregressor_model, cv=5, param_distributions = treeregressor_params, 
                                          scoring=smape_score, n_jobs=-1)
grid_final_treeregressor = RandomizedSearchCV(treeregressor_model, cv=5, param_distributions = treeregressor_params, 
                                        scoring=smape_score, n_jobs=-1)

# %% [markdown]
# Напишем кросс-валидацию для леса.

# %%
grid_rougher_forestregressor = RandomizedSearchCV(forestregressor_model, cv=5, param_distributions = forestregressor_params,
                                            scoring = smape_score, n_jobs=-1)
grid_final_forestregressor = RandomizedSearchCV(forestregressor_model, cv=5, param_distributions = forestregressor_params,
                                          scoring=smape_score, n_jobs=-1)

# %% [markdown]
# Теперь обучим модели и взглянем на наилучшую по параметрам.

# %%
grid_rougher_lasso.fit(x_train, y_train_rougher)
grid_final_lasso.fit(x_train, y_train_final)
# Out:
# RandomizedSearchCV(cv=5,
#                    estimator=Pipeline(steps=[('standardscaler',
#                                               StandardScaler()),
#                                              ('lasso',
#                                               Lasso(random_state=3301))]),
#                    n_jobs=-1,
#                    param_distributions={'lasso__alpha': [0.02, 0.024, 0.025,
#                                                          0.026, 0.03]},
#                    scoring=make_scorer(sMAPE, greater_is_better=False))

# %%
abs(grid_rougher_lasso.best_score_)
# Out:
# 6.547334475472728

# %%
abs(grid_final_lasso.best_score_)
# Out:
# 9.574617259560963

# %%
grid_rougher_treeregressor.fit(x_train, y_train_rougher)
grid_final_treeregressor.fit(x_train, y_train_final)
# Out:
# RandomizedSearchCV(cv=5,
#                    estimator=Pipeline(steps=[('standardscaler',
#                                               StandardScaler()),
#                                              ('decisiontreeregressor',
#                                               DecisionTreeRegressor(random_state=3301))]),
#                    n_jobs=-1,
#                    param_distributions={'decisiontreeregressor__max_depth': range(1, 10)},
#                    scoring=make_scorer(sMAPE, greater_is_better=False))

# %%
abs(grid_rougher_treeregressor.best_score_)
# Out:
# 6.9799194690832085

# %%
abs(grid_final_treeregressor.best_score_)
# Out:
# 9.03352283987598

# %%
grid_rougher_forestregressor.fit(x_train, y_train_rougher)
grid_final_forestregressor.fit(x_train, y_train_final)
# Out:
# RandomizedSearchCV(cv=5,
#                    estimator=Pipeline(steps=[('standardscaler',
#                                               StandardScaler()),
#                                              ('randomforestregressor',
#                                               RandomForestRegressor(random_state=3301))]),
#                    n_jobs=-1,
#                    param_distributions={'randomforestregressor__max_depth': range(1, 10),
#                                         'randomforestregressor__n_estimators': range(10, 61, 10)},
#                    scoring=make_scorer(sMAPE, greater_is_better=False))

# %%
abs(grid_rougher_forestregressor.best_score_)
# Out:
# 7.404292567114943

# %%
abs(grid_final_forestregressor.best_score_)
# Out:
# 8.542644164441864

# %% [markdown]
# Пока самые лучшие параметры прогнозирования эффективности обогащения чернового концентрата у модели Лассо, а финального у модели леса. Посмотрим на финальную оценку и выберем самую минимальную.

# %%
abs(total_sMAPE(grid_rougher_lasso.best_score_, grid_final_lasso.best_score_))
# Out:
# 8.817796563538904

# %%
abs(total_sMAPE(grid_rougher_forestregressor.best_score_, grid_final_forestregressor.best_score_))
# Out:
# 8.258056265110135

# %%
abs(total_sMAPE(grid_rougher_treeregressor.best_score_, grid_final_treeregressor.best_score_))
# Out:
# 8.520121997177787

# %% [markdown]
# Как мы видим, наименьший показатель итоговой sMARE у модели леса, поэтому выбираем лес и смотрим результаты на тестовой выборке.

# %%
rougher_pred = grid_rougher_lasso.predict(x_test)
final_pred = grid_final_lasso.predict(x_test)
total_sMAPE(sMAPE(y_test_rougher, rougher_pred), sMAPE(y_test_final, final_pred))
# Out:
# 6.902164774175041

# %% [markdown]
# Оценка получена. Теперь напишем константную модель и посмотрим верно ли предсказывает наша модель по сравнению с ней. Пусть наша константная модель предсказывает средние значения.

# %%
constant_rougher = make_pipeline(StandardScaler(), DummyRegressor(strategy='mean'))
constant_final = make_pipeline(StandardScaler(), DummyRegressor(strategy='mean'))

# %% [markdown]
# Теперь обучим ещё на наших выборках.

# %%
constant_rougher.fit(x_train, y_train_rougher)
constant_final.fit(x_train, y_train_final)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('dummyregressor', DummyRegressor())])

# %%
constant_rougher_pred = constant_rougher.predict(x_test)
constant_final_pred = constant_final.predict(x_test)

# %%
total_sMAPE(sMAPE(y_test_rougher, constant_rougher_pred), sMAPE(y_test_final, constant_final_pred))
# Out:
# 7.50678973810227

# %% [markdown]
# **Вывод:**
#
# Как мы видим, модель, которая лучшим образом предсказывает долю золота в концентратах и хвостах, явилась модель леса с показателем итогового симметричного среднего абсолютного процентного отклонения (sMARE) **6.9**, тогда как константная модель имеет данный показатель в **7.5**.

# %% [markdown]
# **Общие выводы:**
#
# В ходе работы над проектом нами изучены и подготовлены данные (проведена проверка правильности расчета эффективности обогащения, анализ признаков, недоступных в тестовой выборе, предобработка данных); был осуществлен исследовательский анализ данных (изучены изменения концентрации металлов на разных этапах обработки, проведено сравнение распределения размеров гранул сырья в обучающей и тестовой выборках и исследование суммарной концентрации всех веществ на разных этапах); обучена модель, лучшим образом предсказывающая долю золота в концентратах и хвостах, которой явилась модель леса с показателем итогового симметричного среднего абсолютного процентного отклонения (sMARE) **6.9**.
